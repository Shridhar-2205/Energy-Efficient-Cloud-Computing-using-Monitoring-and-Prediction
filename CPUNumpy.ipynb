# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_excel('D:\\Users\\DELL\\Downloads\\DataScience-Python388888888888888\\ab.xlsx')
df.head()
# Out:
#          NR        NT  Time       CPU
# 0  0.066667  0.200000     0  2.733333
# 1  0.000000  0.133333   300  2.000000
# 2  0.000000  0.133333   600  2.933333
# 3  0.133333  0.200000   900  2.066667
# 4  0.066667  0.266667  1200  2.666667

# %%
conv_arr= df.values

# %%
df.as_matrix(colu
# Out:
# array([[  6.66666670e-02,   2.00000000e-01,   0.00000000e+00,
#           2.73333333e+00],
#        [  0.00000000e+00,   1.33333333e-01,   3.00000000e+02,
#           2.00000000e+00],
#        [  0.00000000e+00,   1.33333333e-01,   6.00000000e+02,
#           2.93333333e+00],
#        [  1.33333333e-01,   2.00000000e-01,   9.00000000e+02,
#           2.06666667e+00],
#        [  6.66666670e-02,   2.66666667e-01,   1.20000000e+03,
#           2.66666667e+00],
#        [  6.66666670e-02,   2.66666667e-01,   1.50000000e+03,
#           2.33333333e+00],
#        [  1.33333333e-01,   1.33333333e-01,   1.80000000e+03,
#           2.40000000e+00],
#        [  1.33333333e-01,   2.00000000e-01,   2.10000000e+03,
#           2.60000000e+00],
#        [  6.66666670e-02,   2.00000000e-01,   2.40000000e+03,
#           2.33333333e+00],
#        [  1.33333333e-01,   2.00000000e-01,   2.70000000e+03,
#           2.66666667e+00],
#        [  6.66666670e-02,   2.00000000e-01,   3.00000000e+03,
# ...

# %%
print(df.columns[])
# Out:
# NR

# %%
conv_arr= df.values

# %%
arr1 = np.delete(conv_arr,[1,2,3],axis=1) 
arr2 = np.delete(conv_arr,[0,2,3],axis=1) 
arr3 = np.delete(conv_arr,[0,1,3],axis=1) 
arr4 = np.delete(conv_arr,[0,1,2],axis=1)

# %%
arr1 = arr1.ravel()
arr2 = arr2.ravel()
arr3 = arr3.ravel()
arr4 = arr4.ravel()

# %%
print(arr1)
# Out:
# [ 0.06666667  0.          0.          0.13333333  0.06666667  0.06666667
#   0.13333333  0.13333333  0.06666667  0.13333333  0.06666667  0.06666667
#   0.13333333  0.          0.          0.06666667  0.06666667  0.26666667
#   0.13333333  0.06666667  0.06666667  0.06666667  0.06666667  0.
#   0.13333333  0.          0.13333333  0.13333333  0.26666667  0.06666667
#   0.06666667  0.          0.          0.13333333  0.          0.13333333
#   0.13333333  0.06666667  0.          0.06666667  0.06666667  0.06666667
#   0.06666667  0.          0.06666667  0.13333333  0.13333333  0.06666667
#   0.13333333  0.13333333  0.          0.13333333  0.06666667  0.06666667
#   0.13333333  0.          0.06666667  0.06666667  0.2       ]
