# %%
import os

import numpy as np
import pandas as pd
import tensorflow as tf

from energy_py import Runner
from energy_py.agents import DQN
from energy_py.envs import BatteryEnv

# %%
#  set random seeds for repeatability
np.random.seed(42)
tf.set_random_seed(42)

# %%
#  define a total number of steps for the experiment to run
TOTAL_STEPS = 100000

agent_config = {'discount': 0.97,                 #  the discount rate
                'tau': 0.01,                     #  parameter that controls the copying of weights from online to target network
                'total_steps': TOTAL_STEPS,   
                'batch_size': 12,                 #  size of the minibatches used for learning
                'layers': (20, 20),               #  structure of the neural network used to approximate Q(s,a)
                'learning_rate': 0.01,          #  controls the stength of weight updates during learning       
                'epsilon_decay_fraction': 0.3,    #  a fraction as % of total steps where epsilon decayed from 1.0 to 0.1
                'memory_fraction': 0.9,           #  the size of the replay memory as a % of total steps
                'memory_type': 'deque',           #  the replay memory implementation we want
                'process_observation': 'standardizer',
                'process_target': 'normalizer'}    

#  we just need to let our env know where our state.csv and observation.csv are (data_path)
env = BatteryEnv(data_path=os.getcwd())

# %%
#  Runner is a class that helps us with experiments - tracking rewards, writing environment info to csv and managing TensorBoard
#  in this notebook we just use it to track rewards for us
runner = Runner()

#  initialize Tensorflow machinery
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    #  add the tf session and t-+he environment to the agent config dictionary
    #  and initialize the agent
    agent_config['sess'] = sess
    agent_config['env'] = env
    agent = DQN(**agent_config)
    
    #  initial values for the step and episode number
    step, episode = 0, 0

    #  outer while loop runs through multiple episodes
    while step < TOTAL_STEPS:
        episode += 1
        done = False
        observation = env.reset()
        
        while not done:
            step += 1
            action = agent.act(observation)
            
            next_observation, reward, done, info = env.step(action)
            
            #  store the experience
            agent.remember(observation, action, reward,
                           next_observation, done)
            
            #  moving to the next time step
            observation = next_observation
            #  saving the reward 
            runner.append(reward)
            
            #  we don't start learning until the memory is half full
            if step > int(agent.memory.size * 0.5):  #set threshold to start learning
                train_info = agent.learn()
        
        if episode % 500 == 0:
            print('progress - {:.1f}% - episode {:.0f} - run time {:.2f} - episode reward {:.2f} - avg rewards {:.2f}'.format(100*step/TOTAL_STEPS,
                                                                                                                              episode,
                                                                                                                              runner.calc_time(),
                                                                                                                              sum(runner.ep_rewards),
                                                                                                                              runner.avg_rew))
        #  the report method should be run at the end of each episode
        runner.report({'ep': episode,
                       'step': step})
# Out:
# copying ['hidden_layer_1', 'Variable:0'] to ['hidden_layer_1', 'Variable:0']
# copying ['hidden_layer_1', 'Variable_1:0'] to ['hidden_layer_1', 'Variable_1:0']
# copying ['input_layer', 'Variable:0'] to ['input_layer', 'Variable:0']
# copying ['input_layer', 'Variable_1:0'] to ['input_layer', 'Variable_1:0']
# copying ['output_layer', 'Variable:0'] to ['output_layer', 'Variable:0']
# copying ['output_layer', 'Variable_1:0'] to ['output_layer', 'Variable_1:0']
# copying ['hidden_layer_1', 'Variable:0'] to ['hidden_layer_1', 'Variable:0']
# copying ['hidden_layer_1', 'Variable_1:0'] to ['hidden_layer_1', 'Variable_1:0']
# copying ['input_layer', 'Variable:0'] to ['input_layer', 'Variable:0']
# copying ['input_layer', 'Variable_1:0'] to ['input_layer', 'Variable_1:0']
# copying ['output_layer', 'Variable:0'] to ['output_layer', 'Variable:0']
# copying ['output_layer', 'Variable_1:0'] to ['output_layer', 'Variable_1:0']
# progress - 23.5% - episode 500 - run time 1.46 - episode reward -17.09 - avg rewards -11.87
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-533acdb9240d> in <module>()
#      24         while not done:
#      25             step += 1
# ---> 26             action = agent.act(observation)
#      27
#      28             next_observation, reward, done, info = env.step(action)
#
# ~\Anaconda3\cloud_envi\cloud30april\energy_py\agents\agent.py in act(self, observation)
#     129
#     130         assert observation.shape[0] == 1
# --> 131         return self._act(observation)
#     132
#     133     def learn(self, **kwargs):
#
# ~\Anaconda3\cloud_envi\cloud30april\energy_py\agents\dqn.py in _act(self, observation)
#     248             logger.debug('acting randomly - action is {}'.format(action))
#     249         else:
# --> 250             _, _, action = self.predict_online(observation)
#     251             logger.debug('acting optimally action is {}'.format(action))
#     252
#
# ~\Anaconda3\cloud_envi\cloud30april\energy_py\agents\dqn.py in predict_online(self, observation)
#     208
#     209         logger.debug('predict_online - observation {}'.format(obs))
# --> 210         logger.debug('predict_online - pred_q_values {}'.format(q_vals))
#     211         logger.debug('predict_online - max_q {}'.format(max_q))
#     212         logger.debug('predict_online - action_index {}'.format(action_idx))
#
# ~\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in array_str(a, max_line_width, precision, suppress_small)
#    1400         return str(a[()])
#    1401
# -> 1402     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#    1403
#    1404 def set_string_function(f, repr=True):
#
# ~\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, **kwarg)
#     620         return "[]"
#     621
# --> 622     return _array2string(a, options, separator, prefix)
#     623
#     624
#
# ~\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in wrapper(self, *args, **kwargs)
#     420             repr_running.add(key)
#     421             try:
# --> 422                 return f(self, *args, **kwargs)
#     423             finally:
#     424                 repr_running.discard(key)
#
# ~\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in _array2string(a, options, separator, prefix)
#     451     lst = _formatArray(a, format_function, options['linewidth'],
#     452                        next_line_prefix, separator, options['edgeitems'],
# --> 453                        summary_insert, options['legacy'])
#     454     return lst
#     455
#
# ~\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in _formatArray(a, format_function, line_width, next_line_prefix, separator, edge_items, summary_insert, legacy)
#     747         index=(),
#     748         hanging_indent=next_line_prefix,
# --> 749         curr_width=line_width)
#     750
#     751
#
# ~\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in recurser(index, hanging_indent, curr_width)
#     736                 s += hanging_indent + nested + line_sep
#     737
# --> 738             nested = recurser(index + (-1,), next_hanging_indent, next_width)
#     739             s += hanging_indent + nested
#     740
#
# ~\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in recurser(index, hanging_indent, curr_width)
#     702
#     703             for i in range(trailing_items, 1, -1):
# --> 704                 word = recurser(index + (-i,), next_hanging_indent, next_width)
#     705                 s, line = _extendLine(
#     706                     s, line, word, elem_width, hanging_indent, legacy)
#
# ~\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in recurser(index, hanging_indent, curr_width)
#     656
#     657         if axes_left == 0:
# --> 658             return format_function(a[index])
#     659
#     660         # when recursing, add a space to align with the [ added, and reduce the
#
# ~\Anaconda3\lib\site-packages\numpy\core\arrayprint.py in __call__(self, x)
#     861
#     862     def __call__(self, x):
# --> 863         if not np.isfinite(x):
#     864             with errstate(invalid='ignore'):
#     865                 if np.isnan(x):
#
# KeyboardInterrupt:

# %%
#  plot rewards

import matplotlib.pyplot as plt

episode_rewards = runner.global_rewards
plt.plot(episode_rewards)

# %%
#  we can also look at what happened in our last episode
ep_hist = pd.DataFrame.from_dict(info)
fd = pd.DataFrame.from_dict(info)

fd.columns = ['action','done','cpu_utilization','gross_rate','losses','net_stored','new_rate','next_observation','next_state','observation','old_rate','reward','state','steps']
fd =fd.drop('done',1)
#fd.columns = ['action', 'done','cpu_util']
fd.head()
#print(fd['done'],fd['action'])
#ep_hist.head()
# Out:
#                                       action  cpu_utilization  gross_rate  \
# 0  [0.10526315789473684, 0.5263157894736842]        73.366667    0.000000
# 1                 [0.10526315789473684, 2.0]        73.700000    0.000000
# 2  [0.21052631578947367, 0.5263157894736842]        73.400000    0.000000
# 3  [1.4736842105263157, 0.10526315789473684]        73.333333    1.368421
# 4   [1.4736842105263157, 0.5263157894736842]        73.533333    0.947368
#
#      losses  net_stored  new_rate  \
# 0  0.000000    0.000000  0.000000
# 1  0.000000    0.000000  0.000000
# 2  0.000000    0.000000  0.000000
# 3  0.011404    0.102632  0.102632
# 4  0.007895    0.071053  0.173684
#
#                                     next_observation  \
# 0  [[50.0, 50.0, 50.0, 100.0, 100.0, 1.0, 1.0, 0.0]]
# 1  [[50.0, 50.0, 100.0, 100.0, 100.0, 2.0, 1.0, 0...
# 2  [[50.0, 100.0, 100.0, 100.0, 100.0, 3.0, 1.0, ...
# 3  [[100.0, 100.0, 100.0, 100.0, 100.0, 4.0, 1.0,...
# 4  [[100.0, 100.0, 100.0, 100.0, -50.0, 5.0, 1.0,...
#
#                              next_state  \
# 0                         [[73.7, 0.0]]
# 1                         [[73.4, 0.0]]
# 2                  [[73.33333333, 0.0]]
# 3  [[73.53333333, 0.10263157894736841]]
# 4  [[73.16666667, 0.17368421052631577]]
#
#                                          observation  old_rate    reward  \
# 0   [[50.0, 50.0, 50.0, 50.0, 100.0, 0.0, 1.0, 0.0]]  0.000000 -0.000000
# 1  [[50.0, 50.0, 50.0, 100.0, 100.0, 1.0, 1.0, 0.0]]  0.000000 -0.000000
# 2  [[50.0, 50.0, 100.0, 100.0, 100.0, 2.0, 1.0, 0...  0.000000 -0.000000
# 3  [[50.0, 100.0, 100.0, 100.0, 100.0, 3.0, 1.0, ...  0.000000 -8.362573
# 4  [[100.0, 100.0, 100.0, 100.0, 100.0, 4.0, 1.0,...  0.102632 -5.805263
#
#                                   state  steps
# 0                  [[73.36666667, 0.0]]      1
# 1                         [[73.7, 0.0]]      2
# 2                         [[73.4, 0.0]]      3
# 3                  [[73.33333333, 0.0]]      4
# 4  [[73.53333333, 0.10263157894736841]]      5

# %%
#plt.plot(ep_hist.loc[:, 'new_charge'])
plt.plot(fd.loc[:, 'new_rate'])

# %%
print('Loss function')
plt.plot(fd.loc[:, 'losses'])
# Out:
# Loss function

# %%
#plt.plot(ep_hist.loc[:, 'electricity_price'])
plt.plot(fd.loc[:, 'cpu_utilization'])

# %%
ep_hist.loc[:, 'reward'].sum()
# Out:
# -14.166666666666664

# %%
df1=pd.read_excel('C:\\Users\\DELL\\Anaconda3\\cloud30april\\state1.xlsx')
plt.plot(df1['Time'],df1['CPU'])
ax=plt.gca()
ax.set_ylim([0,101])
ax.set_xlim([0,30])
plt.show()
df1.head()
# Out:
#    Time  CPU
# 0     0   34
# 1     5   45
# 2    10   78
# 3    15   88
# 4    20   92
