# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_excel('D:\\Users\\DELL\\Downloads\\DataScience-Python388888888888888\\ab.xlsx')
df.head()
conv_arr= df.values
arr1 = np.delete(conv_arr,[1,2,3],axis=1) 
arr2 = np.delete(conv_arr,[0,2,3],axis=1) 
arr3 = np.delete(conv_arr,[0,1,3],axis=1) 
arr4 = np.delete(conv_arr,[0,1,2],axis=1)
print(arr3)
b=0.4
print(b)
x=arr4.mean()
print(x)
ln=len(arr4)
print(ln)
newar=np.zeros((59,1))
v1=0
newar[0] = x
for i in range(1,59):
 newar[i]= newar[i-1] + b*(arr4[i-1]-newar[i-1])
print(newar)
plt.plot(arr3, newar)
 
plt.xlabel('time')
plt.ylabel('predicted')
 
plt.show()
plt.plot(arr3, arr4)
 
plt.xlabel('time')
plt.ylabel('original')
 
plt.show()
# Out:
# [[    0.]
#  [  300.]
#  [  600.]
#  [  900.]
#  [ 1200.]
#  [ 1500.]
#  [ 1800.]
#  [ 2100.]
#  [ 2400.]
#  [ 2700.]
#  [ 3000.]
#  [ 3300.]
#  [ 3600.]
#  [ 3900.]
#  [ 4200.]
#  [ 4500.]
#  [ 4800.]
#  [ 5100.]
#  [ 5400.]
#  [ 5700.]
#  [ 6000.]
#  [ 6300.]
#  [ 6600.]
#  [ 6900.]
#  [ 7200.]
#  [ 7500.]
#  [ 7800.]
#  [ 8100.]
#  [ 8400.]
#  [ 8700.]
#  [ 9000.]
#  [ 9300.]
#  [ 9600.]
#  [ 9900.]
#  [10200.]
#  [10500.]
#  [10800.]
#  [11100.]
#  [11400.]
#  [11700.]
#  [12000.]
#  [12300.]
#  [12600.]
#  [12900.]
#  [13200.]
#  [13500.]
#  [13800.]
#  [14100.]
#  [14400.]
#  [14700.]
#  [15000.]
#  [15300.]
#  [15600.]
#  [15900.]
#  [16200.]
#  [16500.]
#  [16800.]
#  [17100.]
#  [17400.]]
# 0.4
# 2.4768361582033895
# 59
# [[2.47683616]
#  [2.57943503]
#  [2.34766102]
#  [2.58192994]
#  [2.37582463]
#  [2.49216145]
#  [2.4286302 ]
#  [2.41717812]
#  [2.49030687]
#  [2.42751746]
#  [2.52317714]
#  [2.31390628]
#  [2.58834377]
#  [2.4063396 ]
#  [2.51047042]
#  [2.43961559]
#  [2.53043602]
#  [2.42492828]
#  [2.3882903 ]
#  [2.52630751]
#  [2.31578451]
#  [2.5894707 ]
#  [2.35368242]
#  [2.47887612]
#  [2.44732567]
#  [2.53506207]
#  [2.45437058]
#  [2.43262235]
#  [2.60624007]
#  [2.44374404]
#  [2.61291309]
#  [2.36774786]
#  [2.54064871]
#  [2.40438923]
#  [2.5093002 ]
#  [2.43891346]
#  [2.39668141]
#  [2.50467551]
#  [2.43613864]
#  [2.52834985]
#  [2.31700991]
#  [2.59020595]
#  [2.35412357]
#  [2.55914081]
#  [2.46881782]
#  [2.54795736]
#  [2.56877441]
#  [2.50126465]
#  [2.59409212]
#  [2.43645527]
#  [2.66187316]
#  [2.3971239 ]
#  [2.50494101]
#  [2.43629794]
#  [2.44844543]
#  [2.48240059]
#  [2.44944035]
#  [2.53633088]
#  [2.32179853]]
